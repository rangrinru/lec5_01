# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.3'

# %%
# status initialize

import os

os.environ['CUDA_VISIBLE_DEVICES'] = '1'

with tf.Graph().as_default():
  gpu_options = tf.GPUOptions(allow_growth=True)

# %%
import os
import random
import fnmatch
import datetime
import pickle
import numpy as np
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"

'''import pandas as pd
pd.set_option('display.width', 300)
pd.set_option('display.float_format', '{:,.4f}'.format)
pd.set_option('display.max_colwidth', 200)'''

import pandas as pd
import tensorflow as tf
import tensorflow.keras

print(tf.__version__)
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

print('tf.__version__:', tf.__version__)
print('keras__version__:', tf.keras.__version__)

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

#import colab
#from imgaug import augmenters as img_aug
import matplotlib.pyplot as plt
import matplotlib.image as mping
from PIL import Image
# Out:
# 1.15.3
# tf.__version__: 1.15.3
# keras__version__: 2.2.4-tf

# %%
data_dir = "crop_img"
file_list = os.listdir(data_dir)
image_paths = []
steering_angles = []
pattern ="*.png"
for filename in file_list:
    if fnmatch.fnmatch(filename, pattern):
        image_paths.append(os.path.join(data_dir, filename))
        angle = int(filename[-7:-4])
        steering_angles.append(angle)
print('image_paths', image_paths)
print('steering_angles', steering_angles)
image_index = 1
plt.imshow(Image.open(image_paths[image_index]))
print("image_path: ", image_paths[image_index])
print("steering_Angle: ", steering_angles[image_index])
df = pd.DataFrame()
df['ImagePath'] = image_paths
df['Angle'] = steering_angles
# Out:
# image_paths ['crop_img/train1_00105_000.png', 'crop_img/train1_00091_000.png', 'crop_img/train1_00090_000.png', 'crop_img/train1_00102_002.png', 'crop_img/train1_00017_000.png', 'crop_img/train1_00009_000.png', 'crop_img/train1_00059_000.png', 'crop_img/train1_00055_000.png', 'crop_img/train1_00044_001.png', 'crop_img/train1_00083_000.png', 'crop_img/train1_00080_000.png', 'crop_img/train1_00074_000.png', 'crop_img/train1_00071_002.png', 'crop_img/train1_00104_002.png', 'crop_img/train1_00066_002.png', 'crop_img/train1_00047_000.png', 'crop_img/train1_00101_002.png', 'crop_img/train1_00023_000.png', 'crop_img/train1_00070_002.png', 'crop_img/train1_00073_002.png', 'crop_img/train1_00008_002.png', 'crop_img/train1_00015_000.png', 'crop_img/train1_00016_002.png', 'crop_img/train1_00072_002.png', 'crop_img/train1_00034_002.png', 'crop_img/train1_00013_000.png', 'crop_img/train1_00041_000.png', 'crop_img/train1_00069_002.png', 'crop_img/train1_00079_002.png', 'crop_img/train1_00004_000.png', 'crop_img/train1_00100_002.png', 'crop_img/train1_00045_000.png', 'crop_img/train1_00024_002.png', 'crop_img/train1_00068_002.png', 'crop_img/train1_00062_002.png', 'crop_img/train1_00001_000.png', 'crop_img/train1_00081_000.png', 'crop_img/train1_00048_001.png', 'crop_img/train1_00002_000.png', 'crop_img/train1_00025_000.png', 'crop_img/train1_00018_000.png', 'crop_img/train1_00007_000.png', 'crop_img/train1_00103_000.png', 'crop_img/train1_00035_000.png', 'crop_img/train1_00014_002.png', 'crop_img/train1_00088_000.png', 'crop_img/train1_00098_000.png', 'crop_img/train1_00026_002.png', 'crop_img/train1_00032_002.png', 'crop_img/train1_00084_000.png', 'crop_img/train1_00078_002.png', 'crop_img/train1_00031_000.png', 'crop_img/train1_00064_002.png', 'crop_img/train1_00042_001.png', 'crop_img/train1_00027_000.png', 'crop_img/train1_00097_002.png', 'crop_img/train1_00086_000.png', 'crop_img/train1_00012_002.png', 'crop_img/train1_00085_000.png', 'crop_img/train1_00022_002.png', 'crop_img/train1_00011_000.png', 'crop_img/train1_00087_000.png', 'crop_img/train1_00046_001.png', 'crop_img/train1_00077_002.png', 'crop_img/train1_00049_000.png', 'crop_img/train1_00089_000.png', 'crop_img/train1_00037_000.png', 'crop_img/train1_00003_000.png', 'crop_img/train1_00028_002.png', 'crop_img/train1_00038_002.png', 'crop_img/train1_00020_002.png', 'crop_img/train1_00029_000.png', 'crop_img/train1_00040_001.png', 'crop_img/train1_00060_002.png', 'crop_img/train1_00030_002.png', 'crop_img/train1_00053_000.png', 'crop_img/train1_00075_002.png', 'crop_img/train1_00106_000.png', 'crop_img/train1_00076_002.png', 'crop_img/train1_00099_000.png', 'crop_img/train1_00057_000.png', 'crop_img/train1_00021_000.png', 'crop_img/train1_00033_000.png', 'crop_img/train1_00050_001.png', 'crop_img/train1_00063_000.png', 'crop_img/train1_00061_000.png', 'crop_img/train1_00095_002.png', 'crop_img/train1_00039_000.png', 'crop_img/train1_00094_002.png', 'crop_img/train1_00093_002.png', 'crop_img/train1_00058_002.png', 'crop_img/train1_00005_001.png', 'crop_img/train1_00082_000.png', 'crop_img/train1_00036_002.png', 'crop_img/train1_00000_000.png', 'crop_img/train1_00043_000.png', 'crop_img/train1_00006_002.png', 'crop_img/train1_00010_002.png', 'crop_img/train1_00067_000.png', 'crop_img/train1_00051_000.png', 'crop_img/train1_00096_000.png', 'crop_img/train1_00065_000.png', 'crop_img/train1_00019_000.png', 'crop_img/train1_00092_002.png', 'crop_img/train1_00054_002.png', 'crop_img/train1_00056_002.png', 'crop_img/train1_00052_002.png']
# steering_angles [0, 0, 0, 2, 0, 0, 0, 0, 1, 0, 0, 0, 2, 2, 2, 0, 2, 0, 2, 2, 2, 0, 2, 2, 2, 0, 0, 2, 2, 0, 2, 0, 2, 2, 2, 0, 0, 1, 0, 0, 0, 0, 0, 0, 2, 0, 0, 2, 2, 0, 2, 0, 2, 1, 0, 2, 0, 2, 0, 2, 0, 0, 1, 2, 0, 0, 0, 0, 2, 2, 2, 0, 1, 2, 2, 0, 2, 0, 2, 0, 0, 0, 0, 1, 0, 0, 2, 0, 2, 2, 2, 1, 0, 2, 0, 0, 2, 2, 0, 0, 0, 0, 0, 2, 2, 2, 2]
# image_path:  crop_img/train1_00091_000.png
# steering_Angle:  0

# %%
num_of_bins = 10
hist, bins = np.histogram(df['Angle'], num_of_bins)
print(hist)
print(bins)
fig, axes = plt.subplots(1,1,figsize=(10,4))
axes.hist(df['Angle'], bins=num_of_bins, width=1, color='blue')
# Out:
# [56  0  0  0  0  7  0  0  0 44]
# [0.  0.2 0.4 0.6 0.8 1.  1.2 1.4 1.6 1.8 2. ]
# (array([56.,  0.,  0.,  0.,  0.,  7.,  0.,  0.,  0., 44.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <a list of 10 Patch objects>)

# %%
'''s = np.array(steering_angles)
angle0=np.where(s==0)
print(angle0)
angle0=np.where(s==45)
print(angle0)
angle0=np.where(s==90)
print(angle0)
angle0=np.where(s==135)
print(angle0)'''

s = np.array(steering_angles)
new_angles = np.copy(steering_angles)
new_angles[np.where(s==0)] = 0
new_angles[np.where(s==45)] = 1
new_angles[np.where(s==135)] = 2
print(new_angles)
print(steering_angles)
print(len(np.where(new_angles==0)[0]))
print(len(np.where(new_angles==1)[0]))
print(len(np.where(new_angles==2)[0]))
#print(len(new_angles))
df['Angle'] = new_angles
# Out:
# [0 0 0 2 0 0 0 0 1 0 0 0 2 2 2 0 2 0 2 2 2 0 2 2 2 0 0 2 2 0 2 0 2 2 2 0 0
#  1 0 0 0 0 0 0 2 0 0 2 2 0 2 0 2 1 0 2 0 2 0 2 0 0 1 2 0 0 0 0 2 2 2 0 1 2
#  2 0 2 0 2 0 0 0 0 1 0 0 2 0 2 2 2 1 0 2 0 0 2 2 0 0 0 0 0 2 2 2 2]
# [0, 0, 0, 2, 0, 0, 0, 0, 1, 0, 0, 0, 2, 2, 2, 0, 2, 0, 2, 2, 2, 0, 2, 2, 2, 0, 0, 2, 2, 0, 2, 0, 2, 2, 2, 0, 0, 1, 0, 0, 0, 0, 0, 0, 2, 0, 0, 2, 2, 0, 2, 0, 2, 1, 0, 2, 0, 2, 0, 2, 0, 0, 1, 2, 0, 0, 0, 0, 2, 2, 2, 0, 1, 2, 2, 0, 2, 0, 2, 0, 0, 0, 0, 1, 0, 0, 2, 0, 2, 2, 2, 1, 0, 2, 0, 0, 2, 2, 0, 0, 0, 0, 0, 2, 2, 2, 2]
# 56
# 7
# 44

# %%
X_train, X_valid, y_train, y_valid = train_test_split(image_paths, new_angles, test_size=0.2)
print("Training data: {}, Validation data : {}".format(len(X_train), len(X_valid)))

fig, axes = plt.subplots(1,2, figsize=(12,4))
axes[0].hist(y_train, bins=num_of_bins, width=1, color='blue')
axes[0].set_title("Training data")
axes[1].hist(y_valid, bins=num_of_bins, width=1, color='red')
axes[1].set_title("Validation data")
# Out:
# Training data: 85, Validation data : 22
# Text(0.5, 1.0, 'Validation data')

# %%
for a, b in zip(X_train, y_train):
    print(a,b)
# Out:
# crop_img/train1_00060_002.png 2
# crop_img/train1_00087_000.png 0
# crop_img/train1_00007_000.png 0
# crop_img/train1_00092_002.png 2
# crop_img/train1_00102_002.png 2
# crop_img/train1_00079_002.png 2
# crop_img/train1_00083_000.png 0
# crop_img/train1_00085_000.png 0
# crop_img/train1_00098_000.png 0
# crop_img/train1_00106_000.png 0
# crop_img/train1_00025_000.png 0
# crop_img/train1_00021_000.png 0
# crop_img/train1_00078_002.png 2
# crop_img/train1_00075_002.png 2
# crop_img/train1_00000_000.png 0
# crop_img/train1_00089_000.png 0
# crop_img/train1_00104_002.png 2
# crop_img/train1_00056_002.png 2
# crop_img/train1_00004_000.png 0
# crop_img/train1_00031_000.png 0
# crop_img/train1_00088_000.png 0
# crop_img/train1_00034_002.png 2
# crop_img/train1_00020_002.png 2
# crop_img/train1_00067_000.png 0
# crop_img/train1_00010_002.png 2
# crop_img/train1_00086_000.png 0
# crop_img/train1_00076_002.png 2
# crop_img/train1_00053_000.png 0
# crop_img/train1_00093_002.png 2
# crop_img/train1_00015_000.png 0
# crop_img/train1_00013_000.png 0
# crop_img/train1_00038_002.png 2
# crop_img/train1_00029_000.png 0
# crop_img/train1_00009_000.png 0
# crop_img/train1_00002_000.png 0
# crop_img/train1_00045_000.png 0
# crop_img/train1_00095_002.png 2
# crop_img/train1_00070_002.png 2
# crop_img/train1_00054_002.png 2
# crop_img/train1_00036_002.png 2
# crop_img/train1_00058_002.png 2
# crop_img/train1_00097_002.png 2
# crop_img/train1_00066_002.png 2
# crop_img/train1_00103_000.png 0
# crop_img/train1_00051_000.png 0
# crop_img/train1_00005_001.png 1
# crop_img/train1_00062_002.png 2
# crop_img/train1_00091_000.png 0
# crop_img/train1_00068_002.png 2
# crop_img/train1_00048_001.png 1
# crop_img/train1_00046_001.png 1
# crop_img/train1_00101_002.png 2
# crop_img/train1_00017_000.png 0
# crop_img/train1_00065_000.png 0
# crop_img/train1_00073_002.png 2
# crop_img/train1_00049_000.png 0
# crop_img/train1_00084_000.png 0
# crop_img/train1_00069_002.png 2
# crop_img/train1_00032_002.png 2
# crop_img/train1_00008_002.png 2
# crop_img/train1_00059_000.png 0
# crop_img/train1_00012_002.png 2
# crop_img/train1_00033_000.png 0
# crop_img/train1_00016_002.png 2
# crop_img/train1_00043_000.png 0
# crop_img/train1_00041_000.png 0
# crop_img/train1_00001_000.png 0
# crop_img/train1_00023_000.png 0
# crop_img/train1_00055_000.png 0
# crop_img/train1_00064_002.png 2
# crop_img/train1_00040_001.png 1
# crop_img/train1_00042_001.png 1
# crop_img/train1_00047_000.png 0
# crop_img/train1_00024_002.png 2
# crop_img/train1_00072_002.png 2
# crop_img/train1_00019_000.png 0
# crop_img/train1_00061_000.png 0
# crop_img/train1_00096_000.png 0
# crop_img/train1_00006_002.png 2
# crop_img/train1_00014_002.png 2
# crop_img/train1_00028_002.png 2
# crop_img/train1_00077_002.png 2
# crop_img/train1_00039_000.png 0
# crop_img/train1_00044_001.png 1
# crop_img/train1_00037_000.png 0

# %%
import cv2
def my_imread(image_path):
    #print(image_path)
    image = cv2.imread(image_path)
    return image
def img_preprocess(image):
    image = np.float32(image) / 255.    
    return image
fig, axes = plt.subplots(1,2,figsize=(15,10))
image_ori = my_imread(image_paths[image_index])
image_processed = img_preprocess(image_ori)
axes[0].imshow(image_ori)
axes[0].set_title("ori")
axes[1].imshow(image_processed)
axes[1].set_title("processed")
print(image_ori.shape)
# Out:
# (66, 200, 3)

# %%
def neural_net():
    model = Sequential()
    model.add(Conv2D(16, (5,5), input_shape=(66,200,3), activation='relu'))
    model.add(MaxPool2D((2,2)))
    model.add(Dropout(0.5))
    model.add(Conv2D(32, (5,5), activation='relu'))
    model.add(MaxPool2D((2,2)))
    model.add(Dropout(0.5))
    model.add(Conv2D(32, (5,5), activation='relu'))
    model.add(MaxPool2D((2,2)))
    model.add(Conv2D(32, (3,3), activation='relu'))
    model.add(Dropout(0.5))
    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(100, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(50, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3, activation='softmax'))

    opt = Adam(lr=1e-3)
    loss_fn = tf.keras.losses.SparseCategoricalCrossentropy()
    model.compile(loss=loss_fn, optimizer=opt)

    return model

model = neural_net()
print(model.summary())
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 196, 16)       1216
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 98, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 31, 98, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 27, 94, 32)        12832
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 47, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 13, 47, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 43, 32)         25632
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 21, 32)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 2, 19, 32)         9248
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 19, 32)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1216)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1216)              0
# _________________________________________________________________
# dense (Dense)                (None, 100)               121700
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 153
# =================================================================
# Total params: 175,831
# Trainable params: 175,831
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def image_data_generator(image_paths, steering_angles, batch_size):
    while True:
        batch_images = []
        batch_steering_angles = []
        len_imgs = len(image_paths)
        #print('len_imgs', len_imgs)
        for i in range(batch_size):
            random_index = random.randint(0, len_imgs-1)
            image_path = image_paths[random_index]
            image = my_imread(image_path)
            steering_angle = steering_angles[random_index]

            image = img_preprocess(image)
            batch_images.append(image)
            batch_steering_angles.append(steering_angle)
            #print('batch_images', batch_images)
            #print('batch_steering_angles', batch_steering_angles)
        yield(np.asarray(batch_images), np.asarray(batch_steering_angles))

# %%
ncol = 2
nrow = 2

print(len(X_train))
#print(len(y_train))

X_train_batch, y_train_batch = next(image_data_generator(X_train, y_train, nrow))
X_valid_batch, y_valid_batch = next(image_data_generator(X_valid, y_valid, nrow))

print(len(X_train_batch))
fig, axes = plt.subplots(nrow, ncol, figsize=(15,6))
fig.tight_layout()

for i in range(nrow):
    axes[i][0].imshow(X_train_batch[i])
    axes[i][0].set_title("training, angle={}".format(y_train_batch[i]))
    axes[i][1].imshow(X_valid_batch[i])
    axes[i][1].set_title("validation, angle={}".format(y_valid_batch[i]))
# Out:
# 85
# 2

# %%
import datetime 
save_dir = datetime.datetime.now().strftime('%Y%m%d_%H%M')
model_output_dir = os.path.join(save_dir)
os.mkdir(model_output_dir)
print('model_output_dir ', model_output_dir)
# Out:
# model_output_dir  20251124_0525

# %%
train_bSize = 20
valid_bSize = 100
checkpoint = 'lane_navigation_'+ save_dir + '.h5'
checkpoint_callback = tensorflow.keras.callbacks.ModelCheckpoint(filepath=os.path.join(model_output_dir, checkpoint),\
                                                                 verbose=1, \
                                                                 save_best_only=True)
history = model.fit_generator(image_data_generator(X_train, y_train, batch_size=train_bSize), \
                              steps_per_epoch=len(X_train)/train_bSize,\
                              epochs=100, \
                              validation_data=image_data_generator(X_valid, y_valid, batch_size=valid_bSize), \
                              validation_steps=len(X_valid)/valid_bSize, \
                              verbose=1, \
                              shuffle=1, \
                              callbacks=[checkpoint_callback])
#model.save(os.path.join(model_output_dir, checkpoint))
history_path = os.path.join(model_output_dir, 'history.pickle')
with open(history_path, 'wb') as f:
    pickle.dump(history.history, f, pickle.HIGHEST_PROTOCOL)
# Out:
# Epoch 1/100
# WARNING:tensorflow:OMP_NUM_THREADS is no longer used by the default Keras config. To configure the number of threads, use tf.config.threading APIs.
# 4/4 [===========================>..] - ETA: 0s - loss: 1.1712Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 1.0600
# Epoch 00001: val_loss improved from inf to 4.81835, saving model to 20251124_0525/lane_navigation_20251124_0525.h5
# 5/4 [===================================] - 3s 696ms/step - loss: 1.1495 - val_loss: 4.8183
# Epoch 2/100
# 4/4 [===========================>..] - ETA: 0s - loss: 1.0432Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 1.0387
# Epoch 00002: val_loss improved from 4.81835 to 4.72135, saving model to 20251124_0525/lane_navigation_20251124_0525.h5
# 5/4 [===================================] - 2s 489ms/step - loss: 1.0444 - val_loss: 4.7213
# Epoch 3/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.9838Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 1.0236
# Epoch 00003: val_loss improved from 4.72135 to 4.65263, saving model to 20251124_0525/lane_navigation_20251124_0525.h5
# 5/4 [===================================] - 2s 486ms/step - loss: 1.0090 - val_loss: 4.6526
# Epoch 4/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.9700Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.9969
# Epoch 00004: val_loss improved from 4.65263 to 4.53156, saving model to 20251124_0525/lane_navigation_20251124_0525.h5
# 5/4 [===================================] - 2s 486ms/step - loss: 0.9712 - val_loss: 4.5316
# Epoch 5/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.9080Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.9747
# Epoch 00005: val_loss improved from 4.53156 to 4.43050, saving model to 20251124_0525/lane_navigation_20251124_0525.h5
# 5/4 [===================================] - 2s 476ms/step - loss: 0.9484 - val_loss: 4.4305
# Epoch 6/100
# 4/4 [===========================>..] - ETA: 0s - loss: 1.0425Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 1.0083
# Epoch 00006: val_loss did not improve from 4.43050
# 5/4 [===================================] - 2s 490ms/step - loss: 1.0310 - val_loss: 4.5834
# Epoch 7/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.9529Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 1.0024
# Epoch 00007: val_loss did not improve from 4.43050
# 5/4 [===================================] - 2s 467ms/step - loss: 0.9723 - val_loss: 4.5564
# Epoch 8/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.9109Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.9441
# Epoch 00008: val_loss improved from 4.43050 to 4.29128, saving model to 20251124_0525/lane_navigation_20251124_0525.h5
# 5/4 [===================================] - 2s 485ms/step - loss: 0.9130 - val_loss: 4.2913
# Epoch 9/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.9457Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.9473
# Epoch 00009: val_loss did not improve from 4.29128
# 5/4 [===================================] - 2s 467ms/step - loss: 0.9288 - val_loss: 4.3060
# Epoch 10/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.8846Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.9732
# Epoch 00010: val_loss did not improve from 4.29128
# 5/4 [===================================] - 2s 480ms/step - loss: 0.9007 - val_loss: 4.4236
# Epoch 11/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.8816Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.9604
# Epoch 00011: val_loss did not improve from 4.29128
# 5/4 [===================================] - 2s 474ms/step - loss: 0.8481 - val_loss: 4.3655
# Epoch 12/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.9549Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.9281
# Epoch 00012: val_loss improved from 4.29128 to 4.21885, saving model to 20251124_0525/lane_navigation_20251124_0525.h5
# 5/4 [===================================] - 2s 493ms/step - loss: 0.9356 - val_loss: 4.2188
# Epoch 13/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.8806Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.9054
# Epoch 00013: val_loss improved from 4.21885 to 4.11556, saving model to 20251124_0525/lane_navigation_20251124_0525.h5
# 5/4 [===================================] - 2s 472ms/step - loss: 0.8836 - val_loss: 4.1156
# Epoch 14/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.9200Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.9282
# Epoch 00014: val_loss did not improve from 4.11556
# 5/4 [===================================] - 2s 471ms/step - loss: 0.9139 - val_loss: 4.2191
# Epoch 15/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.9397Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.9620
# Epoch 00015: val_loss did not improve from 4.11556
# 5/4 [===================================] - 2s 478ms/step - loss: 0.9675 - val_loss: 4.3727
# Epoch 16/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.8347Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.9235
# Epoch 00016: val_loss did not improve from 4.11556
# 5/4 [===================================] - 2s 476ms/step - loss: 0.8447 - val_loss: 4.1978
# Epoch 17/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.9213Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.8483
# Epoch 00017: val_loss improved from 4.11556 to 3.85602, saving model to 20251124_0525/lane_navigation_20251124_0525.h5
# 5/4 [===================================] - 2s 472ms/step - loss: 0.9109 - val_loss: 3.8560
# Epoch 18/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.9096Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.9233
# Epoch 00018: val_loss did not improve from 3.85602
# 5/4 [===================================] - 2s 470ms/step - loss: 0.9159 - val_loss: 4.1967
# Epoch 19/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.8816Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.9520
# Epoch 00019: val_loss did not improve from 3.85602
# 5/4 [===================================] - 2s 455ms/step - loss: 0.8747 - val_loss: 4.3273
# Epoch 20/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.8109Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.8983
# Epoch 00020: val_loss did not improve from 3.85602
# 5/4 [===================================] - 2s 460ms/step - loss: 0.7859 - val_loss: 4.0834
# Epoch 21/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.9241Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.8654
# Epoch 00021: val_loss did not improve from 3.85602
# 5/4 [===================================] - 2s 459ms/step - loss: 0.8805 - val_loss: 3.9334
# Epoch 22/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.8875Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.8746
# Epoch 00022: val_loss did not improve from 3.85602
# 5/4 [===================================] - 2s 455ms/step - loss: 0.8686 - val_loss: 3.9755
# Epoch 23/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.8337Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.8972
# Epoch 00023: val_loss did not improve from 3.85602
# 5/4 [===================================] - 2s 459ms/step - loss: 0.8339 - val_loss: 4.0784
# Epoch 24/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.7677Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7739
# Epoch 00024: val_loss improved from 3.85602 to 3.51752, saving model to 20251124_0525/lane_navigation_20251124_0525.h5
# 5/4 [===================================] - 2s 472ms/step - loss: 0.8047 - val_loss: 3.5175
# Epoch 25/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.8590Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7897
# Epoch 00025: val_loss did not improve from 3.51752
# 5/4 [===================================] - 2s 464ms/step - loss: 0.8258 - val_loss: 3.5896
# Epoch 26/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.8198Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.8513
# Epoch 00026: val_loss did not improve from 3.51752
# 5/4 [===================================] - 2s 446ms/step - loss: 0.8369 - val_loss: 3.8697
# Epoch 27/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.8206Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.8503
# Epoch 00027: val_loss did not improve from 3.51752
# 5/4 [===================================] - 2s 460ms/step - loss: 0.8139 - val_loss: 3.8648
# Epoch 28/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.8276Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.8099
# Epoch 00028: val_loss did not improve from 3.51752
# 5/4 [===================================] - 2s 445ms/step - loss: 0.8055 - val_loss: 3.6815
# Epoch 29/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.8018Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7675
# Epoch 00029: val_loss improved from 3.51752 to 3.48875, saving model to 20251124_0525/lane_navigation_20251124_0525.h5
# 5/4 [===================================] - 2s 463ms/step - loss: 0.7925 - val_loss: 3.4888
# Epoch 30/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.7849Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7589
# Epoch 00030: val_loss improved from 3.48875 to 3.44974, saving model to 20251124_0525/lane_navigation_20251124_0525.h5
# 5/4 [===================================] - 2s 463ms/step - loss: 0.7537 - val_loss: 3.4497
# Epoch 31/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.9111Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.8207
# Epoch 00031: val_loss did not improve from 3.44974
# 5/4 [===================================] - 2s 452ms/step - loss: 0.8725 - val_loss: 3.7305
# Epoch 32/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.8002Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7850
# Epoch 00032: val_loss did not improve from 3.44974
# 5/4 [===================================] - 2s 445ms/step - loss: 0.7731 - val_loss: 3.5684
# Epoch 33/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.7975Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7708
# Epoch 00033: val_loss did not improve from 3.44974
# 5/4 [===================================] - 2s 451ms/step - loss: 0.8134 - val_loss: 3.5036
# Epoch 34/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.8458Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6836
# Epoch 00034: val_loss improved from 3.44974 to 3.10713, saving model to 20251124_0525/lane_navigation_20251124_0525.h5
# 5/4 [===================================] - 2s 485ms/step - loss: 0.8069 - val_loss: 3.1071
# Epoch 35/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.7419Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7282
# Epoch 00035: val_loss did not improve from 3.10713
# 5/4 [===================================] - 2s 444ms/step - loss: 0.7414 - val_loss: 3.3099
# Epoch 36/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.7569Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7569
# Epoch 00036: val_loss did not improve from 3.10713
# 5/4 [===================================] - 2s 466ms/step - loss: 0.7155 - val_loss: 3.4403
# Epoch 37/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.7542Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7936
# Epoch 00037: val_loss did not improve from 3.10713
# 5/4 [===================================] - 2s 454ms/step - loss: 0.8337 - val_loss: 3.6075
# Epoch 38/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6818Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7241
# Epoch 00038: val_loss did not improve from 3.10713
# 5/4 [===================================] - 2s 472ms/step - loss: 0.6957 - val_loss: 3.2911
# Epoch 39/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.8293Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6985
# Epoch 00039: val_loss did not improve from 3.10713
# 5/4 [===================================] - 2s 447ms/step - loss: 0.8461 - val_loss: 3.1750
# Epoch 40/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.8240Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6873
# Epoch 00040: val_loss did not improve from 3.10713
# 5/4 [===================================] - 2s 464ms/step - loss: 0.7763 - val_loss: 3.1242
# Epoch 41/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6525Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6700
# Epoch 00041: val_loss improved from 3.10713 to 3.04525, saving model to 20251124_0525/lane_navigation_20251124_0525.h5
# 5/4 [===================================] - 2s 464ms/step - loss: 0.6633 - val_loss: 3.0453
# Epoch 42/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6613Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7448
# Epoch 00042: val_loss did not improve from 3.04525
# 5/4 [===================================] - 2s 462ms/step - loss: 0.6877 - val_loss: 3.3853
# Epoch 43/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6418Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7466
# Epoch 00043: val_loss did not improve from 3.04525
# 5/4 [===================================] - 2s 463ms/step - loss: 0.6415 - val_loss: 3.3936
# Epoch 44/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.7588Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7432
# Epoch 00044: val_loss did not improve from 3.04525
# 5/4 [===================================] - 2s 452ms/step - loss: 0.7381 - val_loss: 3.3780
# Epoch 45/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.7860Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7391
# Epoch 00045: val_loss did not improve from 3.04525
# 5/4 [===================================] - 2s 447ms/step - loss: 0.7398 - val_loss: 3.3597
# Epoch 46/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6565Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7520
# Epoch 00046: val_loss did not improve from 3.04525
# 5/4 [===================================] - 2s 458ms/step - loss: 0.7084 - val_loss: 3.4181
# Epoch 47/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.7599Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.8549
# Epoch 00047: val_loss did not improve from 3.04525
# 5/4 [===================================] - 2s 460ms/step - loss: 0.7642 - val_loss: 3.8858
# Epoch 48/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.7138Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6435
# Epoch 00048: val_loss improved from 3.04525 to 2.92513, saving model to 20251124_0525/lane_navigation_20251124_0525.h5
# 5/4 [===================================] - 2s 451ms/step - loss: 0.6790 - val_loss: 2.9251
# Epoch 49/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.8074Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7087
# Epoch 00049: val_loss did not improve from 2.92513
# 5/4 [===================================] - 2s 460ms/step - loss: 0.8249 - val_loss: 3.2213
# Epoch 50/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6954Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7163
# Epoch 00050: val_loss did not improve from 2.92513
# 5/4 [===================================] - 2s 449ms/step - loss: 0.6939 - val_loss: 3.2557
# Epoch 51/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6616Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6865
# Epoch 00051: val_loss did not improve from 2.92513
# 5/4 [===================================] - 2s 464ms/step - loss: 0.6629 - val_loss: 3.1206
# Epoch 52/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5998Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.5964
# Epoch 00052: val_loss improved from 2.92513 to 2.71094, saving model to 20251124_0525/lane_navigation_20251124_0525.h5
# 5/4 [===================================] - 2s 453ms/step - loss: 0.5858 - val_loss: 2.7109
# Epoch 53/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.7790Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7443
# Epoch 00053: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 454ms/step - loss: 0.7268 - val_loss: 3.3831
# Epoch 54/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6543Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6495
# Epoch 00054: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 451ms/step - loss: 0.6618 - val_loss: 2.9523
# Epoch 55/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6833Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6829
# Epoch 00055: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 452ms/step - loss: 0.6844 - val_loss: 3.1041
# Epoch 56/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6440Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6393
# Epoch 00056: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 456ms/step - loss: 0.6527 - val_loss: 2.9057
# Epoch 57/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6846Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6999
# Epoch 00057: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 457ms/step - loss: 0.6850 - val_loss: 3.1814
# Epoch 58/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5175Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6607
# Epoch 00058: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 466ms/step - loss: 0.5501 - val_loss: 3.0032
# Epoch 59/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.8337Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6900
# Epoch 00059: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 457ms/step - loss: 0.8179 - val_loss: 3.1363
# Epoch 60/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5692Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6881
# Epoch 00060: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 468ms/step - loss: 0.6016 - val_loss: 3.1278
# Epoch 61/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5544Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.8509
# Epoch 00061: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 453ms/step - loss: 0.5593 - val_loss: 3.8677
# Epoch 62/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5938Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6700
# Epoch 00062: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 467ms/step - loss: 0.5786 - val_loss: 3.0453
# Epoch 63/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6598Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6970
# Epoch 00063: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 456ms/step - loss: 0.6793 - val_loss: 3.1682
# Epoch 64/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6522Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6993
# Epoch 00064: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 460ms/step - loss: 0.6141 - val_loss: 3.1786
# Epoch 65/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5951Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7566
# Epoch 00065: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 454ms/step - loss: 0.5883 - val_loss: 3.4389
# Epoch 66/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5990Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6439
# Epoch 00066: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 464ms/step - loss: 0.6078 - val_loss: 2.9270
# Epoch 67/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.7070Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6552
# Epoch 00067: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 452ms/step - loss: 0.7047 - val_loss: 2.9784
# Epoch 68/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5163Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7321
# Epoch 00068: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 459ms/step - loss: 0.5268 - val_loss: 3.3277
# Epoch 69/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5271Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7482
# Epoch 00069: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 462ms/step - loss: 0.5480 - val_loss: 3.4011
# Epoch 70/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6189Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6512
# Epoch 00070: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 454ms/step - loss: 0.5711 - val_loss: 2.9600
# Epoch 71/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6399Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7688
# Epoch 00071: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 475ms/step - loss: 0.6362 - val_loss: 3.4944
# Epoch 72/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5720Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7015
# Epoch 00072: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 443ms/step - loss: 0.6386 - val_loss: 3.1888
# Epoch 73/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5706Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6901
# Epoch 00073: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 459ms/step - loss: 0.5732 - val_loss: 3.1367
# Epoch 74/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6635Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6518
# Epoch 00074: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 467ms/step - loss: 0.6564 - val_loss: 2.9627
# Epoch 75/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5819Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.5973
# Epoch 00075: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 463ms/step - loss: 0.5630 - val_loss: 2.7150
# Epoch 76/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6680Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7189
# Epoch 00076: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 449ms/step - loss: 0.6770 - val_loss: 3.2679
# Epoch 77/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6301Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6314
# Epoch 00077: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 459ms/step - loss: 0.5645 - val_loss: 2.8700
# Epoch 78/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6883Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6693
# Epoch 00078: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 454ms/step - loss: 0.6654 - val_loss: 3.0425
# Epoch 79/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5760Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7417
# Epoch 00079: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 455ms/step - loss: 0.5512 - val_loss: 3.3715
# Epoch 80/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5778Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7405
# Epoch 00080: val_loss did not improve from 2.71094
# 5/4 [===================================] - 2s 448ms/step - loss: 0.5695 - val_loss: 3.3658
# Epoch 81/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5329Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.5885
# Epoch 00081: val_loss improved from 2.71094 to 2.67495, saving model to 20251124_0525/lane_navigation_20251124_0525.h5
# 5/4 [===================================] - 2s 458ms/step - loss: 0.5593 - val_loss: 2.6750
# Epoch 82/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5697Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.8078
# Epoch 00082: val_loss did not improve from 2.67495
# 5/4 [===================================] - 2s 451ms/step - loss: 0.6418 - val_loss: 3.6719
# Epoch 83/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5901Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6886
# Epoch 00083: val_loss did not improve from 2.67495
# 5/4 [===================================] - 2s 446ms/step - loss: 0.6044 - val_loss: 3.1299
# Epoch 84/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.6028Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7580
# Epoch 00084: val_loss did not improve from 2.67495
# 5/4 [===================================] - 2s 460ms/step - loss: 0.6047 - val_loss: 3.4456
# Epoch 85/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5955Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.8491
# Epoch 00085: val_loss did not improve from 2.67495
# 5/4 [===================================] - 2s 440ms/step - loss: 0.6227 - val_loss: 3.8597
# Epoch 86/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.7105Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7011
# Epoch 00086: val_loss did not improve from 2.67495
# 5/4 [===================================] - 2s 470ms/step - loss: 0.7062 - val_loss: 3.1866
# Epoch 87/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5070Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6355
# Epoch 00087: val_loss did not improve from 2.67495
# 5/4 [===================================] - 2s 450ms/step - loss: 0.5575 - val_loss: 2.8886
# Epoch 88/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5675Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6913
# Epoch 00088: val_loss did not improve from 2.67495
# 5/4 [===================================] - 2s 454ms/step - loss: 0.6087 - val_loss: 3.1424
# Epoch 89/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5405Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7939
# Epoch 00089: val_loss did not improve from 2.67495
# 5/4 [===================================] - 2s 445ms/step - loss: 0.5396 - val_loss: 3.6087
# Epoch 90/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5652Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6663
# Epoch 00090: val_loss did not improve from 2.67495
# 5/4 [===================================] - 2s 462ms/step - loss: 0.5435 - val_loss: 3.0287
# Epoch 91/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5801Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7292
# Epoch 00091: val_loss did not improve from 2.67495
# 5/4 [===================================] - 2s 452ms/step - loss: 0.5441 - val_loss: 3.3146
# Epoch 92/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.4733Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6300
# Epoch 00092: val_loss did not improve from 2.67495
# 5/4 [===================================] - 2s 441ms/step - loss: 0.4745 - val_loss: 2.8637
# Epoch 93/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5148Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7843
# Epoch 00093: val_loss did not improve from 2.67495
# 5/4 [===================================] - 2s 463ms/step - loss: 0.5312 - val_loss: 3.5651
# Epoch 94/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5392Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.7072
# Epoch 00094: val_loss did not improve from 2.67495
# 5/4 [===================================] - 2s 452ms/step - loss: 0.5938 - val_loss: 3.2147
# Epoch 95/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.4637Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6093
# Epoch 00095: val_loss did not improve from 2.67495
# 5/4 [===================================] - 2s 459ms/step - loss: 0.4845 - val_loss: 2.7693
# Epoch 96/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.4679Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6777
# Epoch 00096: val_loss did not improve from 2.67495
# 5/4 [===================================] - 2s 453ms/step - loss: 0.4906 - val_loss: 3.0805
# Epoch 97/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5988Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.5946
# Epoch 00097: val_loss did not improve from 2.67495
# 5/4 [===================================] - 2s 466ms/step - loss: 0.5947 - val_loss: 2.7028
# Epoch 98/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.4579Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.6642
# Epoch 00098: val_loss did not improve from 2.67495
# 5/4 [===================================] - 2s 447ms/step - loss: 0.4415 - val_loss: 3.0192
# Epoch 99/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.4507Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.5935
# Epoch 00099: val_loss did not improve from 2.67495
# 5/4 [===================================] - 2s 453ms/step - loss: 0.4457 - val_loss: 2.6978
# Epoch 100/100
# 4/4 [===========================>..] - ETA: 0s - loss: 0.5663Epoch 1/100
# 1/4 [======>.......................] - ETA: 2s - loss: 0.5774
# Epoch 00100: val_loss improved from 2.67495 to 2.62473, saving model to 20251124_0525/lane_navigation_20251124_0525.h5
# 5/4 [===================================] - 2s 456ms/step - loss: 0.5685 - val_loss: 2.6247

# %%
img_path = X_valid[0]
image = my_imread(img_path)
steering_angle = steering_angles[0]
image = img_preprocess(image)
print(image.shape)
print(model.predict(np.expand_dims(image, 0))[0])
print(np.argmax(model.predict(np.expand_dims(image, 0))[0]))
plt.imshow(image)
# Out:
# (66, 200, 3)
# [0.8669361  0.00344315 0.1296208 ]
# 0

# %%
print(model_output_dir)

history_path = os.path.join(model_output_dir, 'history.pickle')
with open(history_path, 'rb') as f:
    history = pickle.load(f)

plt.plot(history['loss'], color='blue')
plt.plot(history['val_loss'], color='red')
plt.legend(['training loss', 'validation loss'])
# Out:
# 20251124_0525
